# %% [markdown]
# <a href="https://colab.research.google.com/github/SrMishima/Probabilidad_Y_Estadistica/blob/main/Unidad3/Programa2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Probabilidad y Estadistica
#
# ## Unidad 3
#
# ### Facilitador: Jose Gabriel Rodriguez Rivas
#
# ### Alumno: Tadeo Salvador Torres Aragón
#
# ### **Programa 2: Valor esperado**

# %%
x = [5, 6, 7, 8, 9, 10]
p = [0.05, 0.10, 0.20, 0.30, 0.25, 0.10]

valor_esperado = 0
for i in range(len(x)):
  xi = x[i]
  pi = p[i]
  producto = xi * pi
  valor_esperado += producto
  print(f"x = {xi}, p = {pi}, x*p = {producto:.2f}")



print(f"\n Valor esperado (Esperanza): {valor_esperado:.2f}")
# Out:
# x = 5, p = 0.05, x*p = 0.25
# x = 6, p = 0.1, x*p = 0.60
# x = 7, p = 0.2, x*p = 1.40
# x = 8, p = 0.3, x*p = 2.40
# x = 9, p = 0.25, x*p = 2.25
# x = 10, p = 0.1, x*p = 1.00
#
#  Valor esperado (Esperanza): 7.90
