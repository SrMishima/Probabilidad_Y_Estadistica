# %% [markdown]
# <a href="https://colab.research.google.com/github/SrMishima/Probabilidad_Y_Estadistica/blob/main/Unidad4/Practica7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Unidad 4
#
# *Practica 7: Distribución Poisson eje.2 .*
#
# Facilitador: José Gabriel Rodriguez Rivas
#
# Alumno: Tadeo Salvador Torres Aragon

# %%
from scipy.stats import poisson
mu = 5000 * 0.001
x = 4
prob = poisson.pmf(x, mu)
print(f"Media: {mu}")
print(f"Probabilidad: {prob}")
# Out:
# Media: 5.0
# Probabilidad: 0.17546736976785063
