# %% [markdown]
# <a href="https://colab.research.google.com/github/SrMishima/Probabilidad_Y_Estadistica/blob/main/Unidad1/Practica3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Probabilidad y Estadistica
#
# ## Unidad 1
#
# ### Facilitador: Jose Gabriel Rodriguez Rivas
#
# ### Alumno: Tadeo Salvador Torres Aragón
#
# ### **Programa 3: Tabla de frecuencias y regla de Sturges.**

# %%
import pandas as pd
import random
edades = []

for i in range(100):
  num_al=random.randint(18,70)
  edades.append(num_al)
print(edades)
# Out:
# [25, 59, 69, 66, 70, 55, 69, 53, 45, 49, 42, 22, 61, 61, 50, 36, 48, 31, 58, 54, 22, 58, 62, 36, 59, 32, 54, 36, 50, 70, 62, 22, 33, 18, 58, 37, 42, 34, 56, 58, 22, 38, 56, 67, 26, 18, 36, 22, 53, 63, 53, 48, 37, 70, 29, 49, 27, 24, 66, 43, 26, 39, 57, 21, 61, 42, 39, 60, 25, 46, 47, 37, 43, 25, 40, 23, 44, 47, 21, 45, 18, 42, 18, 29, 60, 65, 22, 21, 35, 34, 30, 45, 25, 37, 38, 69, 18, 36, 33, 50]

# %%
df = pd.DataFrame(edades, columns=['Edad'])
df.head()
# Out:
#    Edad
# 0    25
# 1    59
# 2    69
# 3    66
# 4    70

# %%
tabla_frecuencias = df['Edad'].value_counts().reset_index()
tabla_frecuencias.columns = ['Edad', 'Frecuencia']
tabla_frecuencias = tabla_frecuencias.sort_values (by='Edad')



print("Tabla de Distribución de Frecuencias:")
tabla_frecuencias
# Out:
# Tabla de Distribución de Frecuencias:
#     Edad  Frecuencia
# 1     18           5
# 13    21           3
# 0     22           6
# 40    23           1
# 35    24           1
# 4     25           4
# 22    26           2
# 36    27           1
# 27    29           2
# 44    30           1
# 31    31           1
# 32    32           1
# 18    33           2
# 23    34           2
# 43    35           1
# 2     36           5
# 6     37           4
# 21    38           2
# 26    39           2
# 39    40           1
# 3     42           4
# 25    43           2
# 41    44           1
# 8     45           3
# 38    46           1
# 29    47           2
# 19    48           2
# 14    49           2
# 10    50           3
# 7     53           3
# 28    54           2
# 30    55           1
# 24    56           2
# 37    57           1
# 5     58           4
# 15    59           2
# 17    60           2
# 9     61           3
# 20    62           2
# 33    63           1
# 42    65           1
# 16    66           2
# 34    67           1
# 11    69           3
# 12    70           3

# %%
tabla_frecuencias['Frec Relativa'] = tabla_frecuencias['Frecuencia']

tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa
# 1     18           5              5
# 13    21           3              3
# 0     22           6              6
# 40    23           1              1
# 35    24           1              1
# 4     25           4              4
# 22    26           2              2
# 36    27           1              1
# 27    29           2              2
# 44    30           1              1
# 31    31           1              1
# 32    32           1              1
# 18    33           2              2
# 23    34           2              2
# 43    35           1              1
# 2     36           5              5
# 6     37           4              4
# 21    38           2              2
# 26    39           2              2
# 39    40           1              1
# 3     42           4              4
# 25    43           2              2
# 41    44           1              1
# 8     45           3              3
# 38    46           1              1
# 29    47           2              2
# 19    48           2              2
# 14    49           2              2
# 10    50           3              3
# 7     53           3              3
# 28    54           2              2
# 30    55           1              1
# 24    56           2              2
# 37    57           1              1
# 5     58           4              4
# 15    59           2              2
# 17    60           2              2
# 9     61           3              3
# 20    62           2              2
# 33    63           1              1
# 42    65           1              1
# 16    66           2              2
# 34    67           1              1
# 11    69           3              3
# 12    70           3              3

# %%
tabla_frecuencias['Frecuencia Porcentual']= tabla_frecuencias['Frecuencia']/100 *100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa  Frecuencia Porcentual
# 1     18           5              5                    5.0
# 13    21           3              3                    3.0
# 0     22           6              6                    6.0
# 40    23           1              1                    1.0
# 35    24           1              1                    1.0
# 4     25           4              4                    4.0
# 22    26           2              2                    2.0
# 36    27           1              1                    1.0
# 27    29           2              2                    2.0
# 44    30           1              1                    1.0
# 31    31           1              1                    1.0
# 32    32           1              1                    1.0
# 18    33           2              2                    2.0
# 23    34           2              2                    2.0
# 43    35           1              1                    1.0
# 2     36           5              5                    5.0
# 6     37           4              4                    4.0
# 21    38           2              2                    2.0
# 26    39           2              2                    2.0
# 39    40           1              1                    1.0
# 3     42           4              4                    4.0
# 25    43           2              2                    2.0
# 41    44           1              1                    1.0
# 8     45           3              3                    3.0
# 38    46           1              1                    1.0
# 29    47           2              2                    2.0
# 19    48           2              2                    2.0
# 14    49           2              2                    2.0
# 10    50           3              3                    3.0
# 7     53           3              3                    3.0
# 28    54           2              2                    2.0
# 30    55           1              1                    1.0
# 24    56           2              2                    2.0
# 37    57           1              1                    1.0
# 5     58           4              4                    4.0
# 15    59           2              2                    2.0
# 17    60           2              2                    2.0
# 9     61           3              3                    3.0
# 20    62           2              2                    2.0
# 33    63           1              1                    1.0
# 42    65           1              1                    1.0
# 16    66           2              2                    2.0
# 34    67           1              1                    1.0
# 11    69           3              3                    3.0
# 12    70           3              3                    3.0

# %%
tabla_frecuencias['Frecuencia Acumulada']= tabla_frecuencias['Frecuencia'].cumsum()
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa  Frecuencia Porcentual  \
# 1     18           5              5                    5.0
# 13    21           3              3                    3.0
# 0     22           6              6                    6.0
# 40    23           1              1                    1.0
# 35    24           1              1                    1.0
# 4     25           4              4                    4.0
# 22    26           2              2                    2.0
# 36    27           1              1                    1.0
# 27    29           2              2                    2.0
# 44    30           1              1                    1.0
# 31    31           1              1                    1.0
# 32    32           1              1                    1.0
# 18    33           2              2                    2.0
# 23    34           2              2                    2.0
# 43    35           1              1                    1.0
# 2     36           5              5                    5.0
# 6     37           4              4                    4.0
# 21    38           2              2                    2.0
# 26    39           2              2                    2.0
# 39    40           1              1                    1.0
# 3     42           4              4                    4.0
# 25    43           2              2                    2.0
# 41    44           1              1                    1.0
# 8     45           3              3                    3.0
# 38    46           1              1                    1.0
# 29    47           2              2                    2.0
# 19    48           2              2                    2.0
# 14    49           2              2                    2.0
# 10    50           3              3                    3.0
# 7     53           3              3                    3.0
# 28    54           2              2                    2.0
# 30    55           1              1                    1.0
# 24    56           2              2                    2.0
# 37    57           1              1                    1.0
# 5     58           4              4                    4.0
# 15    59           2              2                    2.0
# 17    60           2              2                    2.0
# 9     61           3              3                    3.0
# 20    62           2              2                    2.0
# 33    63           1              1                    1.0
# 42    65           1              1                    1.0
# 16    66           2              2                    2.0
# 34    67           1              1                    1.0
# 11    69           3              3                    3.0
# 12    70           3              3                    3.0
#
#     Frecuencia Acumulada
# 1                      5
# 13                     8
# 0                     14
# 40                    15
# 35                    16
# 4                     20
# 22                    22
# 36                    23
# 27                    25
# 44                    26
# 31                    27
# 32                    28
# 18                    30
# 23                    32
# 43                    33
# 2                     38
# 6                     42
# 21                    44
# 26                    46
# 39                    47
# 3                     51
# 25                    53
# 41                    54
# 8                     57
# 38                    58
# 29                    60
# 19                    62
# 14                    64
# 10                    67
# 7                     70
# 28                    72
# 30                    73
# 24                    75
# 37                    76
# 5                     80
# 15                    82
# 17                    84
# 9                     87
# 20                    89
# 33                    90
# 42                    91
# 16                    93
# 34                    94
# 11                    97
# 12                   100

# %%
import math

df= pd.DataFrame({'Edad':edades})
df
# Out:
#     Edad
# 0     25
# 1     59
# 2     69
# 3     66
# 4     70
# ..   ...
# 95    69
# 96    18
# 97    36
# 98    33
# 99    50
#
# [100 rows x 1 columns]

# %%
n= len(edades)

K=int(1 + math.log2(n))

print("Valor de n = ", n, "\nNúmero de intervalos =", K)






tabla_frecuencias=  pd.cut (df['Edad'], bins= K, include_lowest=True).value_counts().reset_index()

tabla_frecuencias.columns = ['Clase', 'Frec']


tabla_frecuencias
# Out:
# Valor de n =  100
# Número de intervalos = 7
#               Clase  Frec
# 0  (17.947, 25.429]    20
# 1  (32.857, 40.286]    19
# 2  (55.143, 62.571]    16
# 3  (47.714, 55.143]    13
# 4  (40.286, 47.714]    13
# 5    (62.571, 70.0]    11
# 6  (25.429, 32.857]     8

# %%
tabla_frecuencias = tabla_frecuencias.sort_values(by='Clase')

tabla_frecuencias
# Out:
#               Clase  Frec
# 0  (17.947, 25.429]    20
# 6  (25.429, 32.857]     8
# 1  (32.857, 40.286]    19
# 4  (40.286, 47.714]    13
# 3  (47.714, 55.143]    13
# 2  (55.143, 62.571]    16
# 5    (62.571, 70.0]    11

# %%
tabla_frecuencias['Frec Rel'] = tabla_frecuencias['Frec']/n

tabla_frecuencias['Frec Porc'] = tabla_frecuencias ['Frec'] / n * 100

tabla_frecuencias['Frec Ac'] = tabla_frecuencias ['Frec'].cumsum()

tabla_frecuencias['Frec Rel Ac']=  tabla_frecuencias['Frec Rel'].cumsum()

tabla_frecuencias ['Frec Porc Ac'] = tabla_frecuencias ['Frec Porc'].cumsum()

print(tabla_frecuencias)
# Out:
#               Clase  Frec  Frec Rel  Frec Porc  Frec Ac  Frec Rel Ac  \
# 0  (17.947, 25.429]    20      0.20       20.0       20         0.20
# 6  (25.429, 32.857]     8      0.08        8.0       28         0.28
# 1  (32.857, 40.286]    19      0.19       19.0       47         0.47
# 4  (40.286, 47.714]    13      0.13       13.0       60         0.60
# 3  (47.714, 55.143]    13      0.13       13.0       73         0.73
# 2  (55.143, 62.571]    16      0.16       16.0       89         0.89
# 5    (62.571, 70.0]    11      0.11       11.0      100         1.00
#
#    Frec Porc Ac
# 0          20.0
# 6          28.0
# 1          47.0
# 4          60.0
# 3          73.0
# 2          89.0
# 5         100.0

# %%
import matplotlib.pyplot as plt

plt.hist(edades,alpha=0.5)
plt.title("Histograma basado en la funcion de matplolib con valores estandar")
# Out:
# Text(0.5, 1.0, 'Histograma basado en la funcion de matplolib con valores estandar')

# %%
plt.hist(df['Edad'], bins=K, alpha = 0.5)

plt.title('Histograma de edades basado en la regla de Sturges')

plt.xlabel('Edades')

plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')
