# %% [markdown]
# <a href="https://colab.research.google.com/github/SrMishima/Probabilidad_Y_Estadistica/blob/main/Unidad2/U2_p2_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Probabilidad y Estadistica
#
# ## Unidad 2
#
# ### Facilitador: Jose Gabriel Rodriguez Rivas
#
# ### Alumno: Tadeo Salvador Torres Aragón
#
# ### **Programa 1: Caracteres alfabéticos y dígitos**

# %%
import math as mt
from itertools import combinations
from itertools import combinations_with_replacement
import numpy as np

# %%
caracteres = ["A", "B", "C", "D", "E", "F", "e", "1", "2", "3", "4", "5"]
n = len(caracteres)
r = 10 # ¿cómo agrupar?

Cn = mt.factorial(n) / (mt.factorial(r) * mt.factorial(n-r))

print ("Existen", Cn, " posibles combinaciones sin repetición del total de", n, " caracteres, en grupos de", r," en ", r)

print ("Aquí las combinaciones")

combinaciones_caracteres = list(combinations(caracteres, r))

# Imprime Las combinaciones

for combinacion in combinaciones_caracteres:
    print (combinacion)
# Out:
# Existen 66.0  posibles combinaciones sin repetición del total de 12  caracteres, en grupos de 10  en  10
# Aquí las combinaciones
# ('A', 'B', 'C', 'D', 'E', 'F', 'e', '1', '2', '3')
# ('A', 'B', 'C', 'D', 'E', 'F', 'e', '1', '2', '4')
# ('A', 'B', 'C', 'D', 'E', 'F', 'e', '1', '2', '5')
# ('A', 'B', 'C', 'D', 'E', 'F', 'e', '1', '3', '4')
# ('A', 'B', 'C', 'D', 'E', 'F', 'e', '1', '3', '5')
# ('A', 'B', 'C', 'D', 'E', 'F', 'e', '1', '4', '5')
# ('A', 'B', 'C', 'D', 'E', 'F', 'e', '2', '3', '4')
# ('A', 'B', 'C', 'D', 'E', 'F', 'e', '2', '3', '5')
# ('A', 'B', 'C', 'D', 'E', 'F', 'e', '2', '4', '5')
# ('A', 'B', 'C', 'D', 'E', 'F', 'e', '3', '4', '5')
# ('A', 'B', 'C', 'D', 'E', 'F', '1', '2', '3', '4')
# ('A', 'B', 'C', 'D', 'E', 'F', '1', '2', '3', '5')
# ('A', 'B', 'C', 'D', 'E', 'F', '1', '2', '4', '5')
# ('A', 'B', 'C', 'D', 'E', 'F', '1', '3', '4', '5')
# ('A', 'B', 'C', 'D', 'E', 'F', '2', '3', '4', '5')
# ('A', 'B', 'C', 'D', 'E', 'e', '1', '2', '3', '4')
# ('A', 'B', 'C', 'D', 'E', 'e', '1', '2', '3', '5')
# ('A', 'B', 'C', 'D', 'E', 'e', '1', '2', '4', '5')
# ('A', 'B', 'C', 'D', 'E', 'e', '1', '3', '4', '5')
# ('A', 'B', 'C', 'D', 'E', 'e', '2', '3', '4', '5')
# ('A', 'B', 'C', 'D', 'E', '1', '2', '3', '4', '5')
# ('A', 'B', 'C', 'D', 'F', 'e', '1', '2', '3', '4')
# ('A', 'B', 'C', 'D', 'F', 'e', '1', '2', '3', '5')
# ('A', 'B', 'C', 'D', 'F', 'e', '1', '2', '4', '5')
# ('A', 'B', 'C', 'D', 'F', 'e', '1', '3', '4', '5')
# ('A', 'B', 'C', 'D', 'F', 'e', '2', '3', '4', '5')
# ('A', 'B', 'C', 'D', 'F', '1', '2', '3', '4', '5')
# ('A', 'B', 'C', 'D', 'e', '1', '2', '3', '4', '5')
# ('A', 'B', 'C', 'E', 'F', 'e', '1', '2', '3', '4')
# ('A', 'B', 'C', 'E', 'F', 'e', '1', '2', '3', '5')
# ('A', 'B', 'C', 'E', 'F', 'e', '1', '2', '4', '5')
# ('A', 'B', 'C', 'E', 'F', 'e', '1', '3', '4', '5')
# ('A', 'B', 'C', 'E', 'F', 'e', '2', '3', '4', '5')
# ('A', 'B', 'C', 'E', 'F', '1', '2', '3', '4', '5')
# ('A', 'B', 'C', 'E', 'e', '1', '2', '3', '4', '5')
# ('A', 'B', 'C', 'F', 'e', '1', '2', '3', '4', '5')
# ('A', 'B', 'D', 'E', 'F', 'e', '1', '2', '3', '4')
# ('A', 'B', 'D', 'E', 'F', 'e', '1', '2', '3', '5')
# ('A', 'B', 'D', 'E', 'F', 'e', '1', '2', '4', '5')
# ('A', 'B', 'D', 'E', 'F', 'e', '1', '3', '4', '5')
# ('A', 'B', 'D', 'E', 'F', 'e', '2', '3', '4', '5')
# ('A', 'B', 'D', 'E', 'F', '1', '2', '3', '4', '5')
# ('A', 'B', 'D', 'E', 'e', '1', '2', '3', '4', '5')
# ('A', 'B', 'D', 'F', 'e', '1', '2', '3', '4', '5')
# ('A', 'B', 'E', 'F', 'e', '1', '2', '3', '4', '5')
# ('A', 'C', 'D', 'E', 'F', 'e', '1', '2', '3', '4')
# ('A', 'C', 'D', 'E', 'F', 'e', '1', '2', '3', '5')
# ('A', 'C', 'D', 'E', 'F', 'e', '1', '2', '4', '5')
# ('A', 'C', 'D', 'E', 'F', 'e', '1', '3', '4', '5')
# ('A', 'C', 'D', 'E', 'F', 'e', '2', '3', '4', '5')
# ('A', 'C', 'D', 'E', 'F', '1', '2', '3', '4', '5')
# ('A', 'C', 'D', 'E', 'e', '1', '2', '3', '4', '5')
# ('A', 'C', 'D', 'F', 'e', '1', '2', '3', '4', '5')
# ('A', 'C', 'E', 'F', 'e', '1', '2', '3', '4', '5')
# ('A', 'D', 'E', 'F', 'e', '1', '2', '3', '4', '5')
# ('B', 'C', 'D', 'E', 'F', 'e', '1', '2', '3', '4')
# ('B', 'C', 'D', 'E', 'F', 'e', '1', '2', '3', '5')
# ('B', 'C', 'D', 'E', 'F', 'e', '1', '2', '4', '5')
# ('B', 'C', 'D', 'E', 'F', 'e', '1', '3', '4', '5')
# ('B', 'C', 'D', 'E', 'F', 'e', '2', '3', '4', '5')
# ('B', 'C', 'D', 'E', 'F', '1', '2', '3', '4', '5')
# ('B', 'C', 'D', 'E', 'e', '1', '2', '3', '4', '5')
# ('B', 'C', 'D', 'F', 'e', '1', '2', '3', '4', '5')
# ('B', 'C', 'E', 'F', 'e', '1', '2', '3', '4', '5')
# ('B', 'D', 'E', 'F', 'e', '1', '2', '3', '4', '5')
# ('C', 'D', 'E', 'F', 'e', '1', '2', '3', '4', '5')
