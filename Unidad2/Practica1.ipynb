# %% [markdown]
# <a href="https://colab.research.google.com/github/SrMishima/Probabilidad_Y_Estadistica/blob/main/Unidad2/Practica1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Probabilidad y Estadistica
#
# ## Unidad 2
#
# ### Facilitador: Jose Gabriel Rodriguez Rivas
#
# ### Alumno: Tadeo Salvador Torres Aragón
#
# ### **Programa 1 : Nombres de personas**

# %%
import math as mt
from itertools import combinations
from itertools import combinations_with_replacement
import numpy as np

# %%
nombres = ["Oscar", "Paco", "Paty", "Laura", "Ruben", "Luis", "Lucy", "Alberto", "Juan", "Danny"]
n = len(nombres)
r = 3

Cn = mt.factorial(n) / (mt.factorial(r) * mt.factorial(n-r))

print("Existen", Cn , " posibles combinaciones sin repeticion del total de ", n ," nombres ", " en grupos de ", r ," en ", r)
print("Aqui las combinaciones")
combinaciones_nombres = list(combinations(nombres, r))


for combinacion in combinaciones_nombres:
    print(combinacion)
# Out:
# Existen 120.0  posibles combinaciones sin repeticion del total de  10  nombres   en grupos de  3  en  3
# Aqui las combinaciones
# ('Oscar', 'Paco', 'Paty')
# ('Oscar', 'Paco', 'Laura')
# ('Oscar', 'Paco', 'Ruben')
# ('Oscar', 'Paco', 'Luis')
# ('Oscar', 'Paco', 'Lucy')
# ('Oscar', 'Paco', 'Alberto')
# ('Oscar', 'Paco', 'Juan')
# ('Oscar', 'Paco', 'Danny')
# ('Oscar', 'Paty', 'Laura')
# ('Oscar', 'Paty', 'Ruben')
# ('Oscar', 'Paty', 'Luis')
# ('Oscar', 'Paty', 'Lucy')
# ('Oscar', 'Paty', 'Alberto')
# ('Oscar', 'Paty', 'Juan')
# ('Oscar', 'Paty', 'Danny')
# ('Oscar', 'Laura', 'Ruben')
# ('Oscar', 'Laura', 'Luis')
# ('Oscar', 'Laura', 'Lucy')
# ('Oscar', 'Laura', 'Alberto')
# ('Oscar', 'Laura', 'Juan')
# ('Oscar', 'Laura', 'Danny')
# ('Oscar', 'Ruben', 'Luis')
# ('Oscar', 'Ruben', 'Lucy')
# ('Oscar', 'Ruben', 'Alberto')
# ('Oscar', 'Ruben', 'Juan')
# ('Oscar', 'Ruben', 'Danny')
# ('Oscar', 'Luis', 'Lucy')
# ('Oscar', 'Luis', 'Alberto')
# ('Oscar', 'Luis', 'Juan')
# ('Oscar', 'Luis', 'Danny')
# ('Oscar', 'Lucy', 'Alberto')
# ('Oscar', 'Lucy', 'Juan')
# ('Oscar', 'Lucy', 'Danny')
# ('Oscar', 'Alberto', 'Juan')
# ('Oscar', 'Alberto', 'Danny')
# ('Oscar', 'Juan', 'Danny')
# ('Paco', 'Paty', 'Laura')
# ('Paco', 'Paty', 'Ruben')
# ('Paco', 'Paty', 'Luis')
# ('Paco', 'Paty', 'Lucy')
# ('Paco', 'Paty', 'Alberto')
# ('Paco', 'Paty', 'Juan')
# ('Paco', 'Paty', 'Danny')
# ('Paco', 'Laura', 'Ruben')
# ('Paco', 'Laura', 'Luis')
# ('Paco', 'Laura', 'Lucy')
# ('Paco', 'Laura', 'Alberto')
# ('Paco', 'Laura', 'Juan')
# ('Paco', 'Laura', 'Danny')
# ('Paco', 'Ruben', 'Luis')
# ('Paco', 'Ruben', 'Lucy')
# ('Paco', 'Ruben', 'Alberto')
# ('Paco', 'Ruben', 'Juan')
# ('Paco', 'Ruben', 'Danny')
# ('Paco', 'Luis', 'Lucy')
# ('Paco', 'Luis', 'Alberto')
# ('Paco', 'Luis', 'Juan')
# ('Paco', 'Luis', 'Danny')
# ('Paco', 'Lucy', 'Alberto')
# ('Paco', 'Lucy', 'Juan')
# ('Paco', 'Lucy', 'Danny')
# ('Paco', 'Alberto', 'Juan')
# ('Paco', 'Alberto', 'Danny')
# ('Paco', 'Juan', 'Danny')
# ('Paty', 'Laura', 'Ruben')
# ('Paty', 'Laura', 'Luis')
# ('Paty', 'Laura', 'Lucy')
# ('Paty', 'Laura', 'Alberto')
# ('Paty', 'Laura', 'Juan')
# ('Paty', 'Laura', 'Danny')
# ('Paty', 'Ruben', 'Luis')
# ('Paty', 'Ruben', 'Lucy')
# ('Paty', 'Ruben', 'Alberto')
# ('Paty', 'Ruben', 'Juan')
# ('Paty', 'Ruben', 'Danny')
# ('Paty', 'Luis', 'Lucy')
# ('Paty', 'Luis', 'Alberto')
# ('Paty', 'Luis', 'Juan')
# ('Paty', 'Luis', 'Danny')
# ('Paty', 'Lucy', 'Alberto')
# ('Paty', 'Lucy', 'Juan')
# ('Paty', 'Lucy', 'Danny')
# ('Paty', 'Alberto', 'Juan')
# ('Paty', 'Alberto', 'Danny')
# ('Paty', 'Juan', 'Danny')
# ('Laura', 'Ruben', 'Luis')
# ('Laura', 'Ruben', 'Lucy')
# ('Laura', 'Ruben', 'Alberto')
# ('Laura', 'Ruben', 'Juan')
# ('Laura', 'Ruben', 'Danny')
# ('Laura', 'Luis', 'Lucy')
# ('Laura', 'Luis', 'Alberto')
# ('Laura', 'Luis', 'Juan')
# ('Laura', 'Luis', 'Danny')
# ('Laura', 'Lucy', 'Alberto')
# ('Laura', 'Lucy', 'Juan')
# ('Laura', 'Lucy', 'Danny')
# ('Laura', 'Alberto', 'Juan')
# ('Laura', 'Alberto', 'Danny')
# ('Laura', 'Juan', 'Danny')
# ('Ruben', 'Luis', 'Lucy')
# ('Ruben', 'Luis', 'Alberto')
# ('Ruben', 'Luis', 'Juan')
# ('Ruben', 'Luis', 'Danny')
# ('Ruben', 'Lucy', 'Alberto')
# ('Ruben', 'Lucy', 'Juan')
# ('Ruben', 'Lucy', 'Danny')
# ('Ruben', 'Alberto', 'Juan')
# ('Ruben', 'Alberto', 'Danny')
# ('Ruben', 'Juan', 'Danny')
# ('Luis', 'Lucy', 'Alberto')
# ('Luis', 'Lucy', 'Juan')
# ('Luis', 'Lucy', 'Danny')
# ('Luis', 'Alberto', 'Juan')
# ('Luis', 'Alberto', 'Danny')
# ('Luis', 'Juan', 'Danny')
# ('Lucy', 'Alberto', 'Juan')
# ('Lucy', 'Alberto', 'Danny')
# ('Lucy', 'Juan', 'Danny')
# ('Alberto', 'Juan', 'Danny')
